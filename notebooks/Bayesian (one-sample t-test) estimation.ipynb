# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Study-description" data-toc-modified-id="Study-description-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Study description</a></span></li><li><span><a href="#Bayesian-estimation-equivalent-of-the-one-sample-t-test" data-toc-modified-id="Bayesian-estimation-equivalent-of-the-one-sample-t-test-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Bayesian estimation equivalent of the one-sample t-test</a></span><ul class="toc-item"><li><span><a href="#The-classic-one-sample-t-test" data-toc-modified-id="The-classic-one-sample-t-test-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>The classic one sample t-test</a></span></li></ul></li><li><span><a href="#Bayesian-inference" data-toc-modified-id="Bayesian-inference-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Bayesian inference</a></span></li><li><span><a href="#Steps-of-Bayesian-data-analysis" data-toc-modified-id="Steps-of-Bayesian-data-analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Steps of Bayesian data analysis</a></span></li><li><span><a href="#Step-1---Identify-the-relevant-data-for-question-under-investigation" data-toc-modified-id="Step-1---Identify-the-relevant-data-for-question-under-investigation-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Step 1 - Identify the relevant data for question under investigation</a></span><ul class="toc-item"><li><span><a href="#Study/data-description" data-toc-modified-id="Study/data-description-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Study/data description</a></span></li><li><span><a href="#Import-data" data-toc-modified-id="Import-data-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Import data</a></span><ul class="toc-item"><li><span><a href="#Clean-the-data" data-toc-modified-id="Clean-the-data-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Clean the data</a></span></li><li><span><a href="#Data-visualisation-and-exploratory-Data-analysis" data-toc-modified-id="Data-visualisation-and-exploratory-Data-analysis-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Data visualisation and exploratory Data analysis</a></span></li></ul></li></ul></li><li><span><a href="#Step-2---Define-the-descriptive-statistical-model-\begin{align*}
# y_i-&amp;\sim-Normal(\mu,-\sigma)-
# \\-\mu-&amp;\sim-Normal(0.5,-0.2)-
# \\-\sigma-&amp;\sim-Exponential(0.1)-
# \end{align*}" data-toc-modified-id="Step-2---Define-the-descriptive-statistical-model-\begin{align*}
# y_i-&amp;\sim-Normal(\mu,-\sigma)-
# \\-\mu-&amp;\sim-Normal(0.5,-0.2)-
# \\-\sigma-&amp;\sim-Exponential(0.1)-
# \end{align*}-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Step 2 - Define the descriptive statistical model <div class="MathJax_Display" style="text-align: center;"></div><script type="math/tex; mode=display" id="MathJax-Element-10">\begin{align*}
# y_i &\sim Normal(\mu, \sigma)
# \\ \mu &\sim Normal(0.5, 0.2)
# \\ \sigma &\sim Exponential(0.1)
# \end{align*}</script></a></span></li><li><span><a href="#Step-3---Specifying-priors" data-toc-modified-id="Step-3---Specifying-priors-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Step 3 - Specifying priors</a></span><ul class="toc-item"><li><span><a href="#Prior-predictive-checks" data-toc-modified-id="Prior-predictive-checks-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Prior predictive checks</a></span><ul class="toc-item"><li><span><a href="#Visualising-priors" data-toc-modified-id="Visualising-priors-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Visualising priors</a></span></li><li><span><a href="#SImulating-data-based-on-priors" data-toc-modified-id="SImulating-data-based-on-priors-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>SImulating data based on priors</a></span></li></ul></li></ul></li><li><span><a href="#Step-4-use-Bayes-rule" data-toc-modified-id="Step-4-use-Bayes-rule-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Step 4 use Bayes rule</a></span></li><li><span><a href="#Stan-model-of-Bayesian-One-sample-t-test" data-toc-modified-id="Stan-model-of-Bayesian-One-sample-t-test-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Stan model of Bayesian One sample t-test</a></span></li><li><span><a href="#Post-model-fit-visualisations---Bayesian-one-sample-Z-test" data-toc-modified-id="Post-model-fit-visualisations---Bayesian-one-sample-Z-test-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Post model fit-visualisations - Bayesian one sample Z-test</a></span><ul class="toc-item"><li><span><a href="#Posterior-distributions-plots" data-toc-modified-id="Posterior-distributions-plots-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Posterior distributions plots</a></span></li><li><span><a href="#Autocorrelation-plots" data-toc-modified-id="Autocorrelation-plots-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Autocorrelation plots</a></span></li><li><span><a href="#MCMC-traceplots" data-toc-modified-id="MCMC-traceplots-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>MCMC traceplots</a></span></li></ul></li><li><span><a href="#Step-5---Posterior-predictive-checks" data-toc-modified-id="Step-5---Posterior-predictive-checks-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Step 5 - Posterior predictive checks</a></span></li><li><span><a href="#Reporting-the-results-of-the-Bayesian-one-sample-t-test-equivalent" data-toc-modified-id="Reporting-the-results-of-the-Bayesian-one-sample-t-test-equivalent-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Reporting the results of the Bayesian one sample t-test equivalent</a></span><ul class="toc-item"><li><span><a href="#Write-up" data-toc-modified-id="Write-up-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span><font size="3">Write up</font></a></span></li></ul></li><li><span><a href="#References" data-toc-modified-id="References-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>References</a></span></li></ul></div>

# %% [markdown]
# The data used here is dowloaded from https://sites.trinity.edu/osl/data-sets-and-activities/t-test-activities and is stored  and called from the data directory in the Github repository of these notebooks

# %%
# Import analysis packages
# %matplotlib inline
import pystan as ps
import numpy as np
import pandas as pd
import seaborn as sns
import arviz as az
import matplotlib.pyplot as plt
import scipy.stats as ss

# %%
#
from IPython.core.display import HTML as Center

Center(""" <style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style> """)
# Out:
#  <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# # Bayesian estimation equivalent of the one-sample t-test
#
# ## The classic one sample t-test
#
# The one sample t-test calculates a t-statistic from calcualting the differnce betweene the dample mean and therised jnown null hypothesis population mean and then finding the quotient of this differnce to the estimated standard error from the sample data.
#
#
# $$ \large t = \frac{\bar{X}-\mu_0}{\frac{S}{\sqrt{N}}}$$
#
# where
#
# $\mu_0 = $ is a theorised costant for the population mean
#
# $\bar{X} = $ sample mean
#
# $N = $ Sample size
#
# $S = $ sample standared deviation
#
# $\frac{S}{\sqrt{N}} = $ estimated standard error
#
#
# With the t statistic then being compared to null sampling distribution to determine p-value is less than or equal to the  𝛼  level determined before the analysis for the NHST.
#
# $$ \large H_0:\bar{X} = \mu_0$$
# $$ \large H_1:\bar{X}\neq \mu_0$$

# %% [markdown]
# # Bayesian inference
# <font size = "3"> Following the quick description of the classic one sample t-test above its important to keep in mind that Bayesian analysis inference are all derived from the applciation of Bayes rule $P(\theta \mid y) = \large \frac{P(y \mid \theta) \, P(\theta)}{P(y)}$ and as such while the following description of the Bayesian model is an equivalent to the Z-test, it is fundamentally different, becuase it uses fully probabilistic modelling and the infernce is not based on sampling distributions</font>
#
# <font size = "1"> For a fuller description see the Practicing Bayesian statistics markdown file within the Github repository.</font>

# %% [markdown]
# # Steps of Bayesian data analysis
#
# <font size = "3"> Kruscke (2015) offers a step by step formulation for how to conduct a Bayesian analysis:
#
# 1. Identify the relevant data for question under investigation.
#
# 2. Define the descriptive (mathematical) model for the data.
#
# 3. Specify the Priors for the model. In the case of scientific research publication is the goal, as such the priors must be accepted by a skeptical audience. Much of this can be achieved using prior predcitve checks to acsetain os the priors are reasonable.
#
# 4. Using Bayes rule estimate the posterior for the parameters of the model using the likelihood and priors. Then interprete and the posterior
#
# 5. Conduct model checks. i.e. Posterior predcitive checks.</font>
#
# <font size = "1">This notebook will follow this approach generally.</font>

# %% [markdown]
# #  Step 1 - Identify the relevant data for question under investigation

# %% [markdown]
# ## Study/data description
#
# The Original research and paper were produced by Mehr, S. A., Song. L. A., & Spelke, E. S. (2016). For 5-month-old infants, melodies are social. Psychological Science, 27, 486-501.
#
# Parents sing to their children which focusses childs attention towards the parent singing. Mehr, Song, and Spelke (2016), attempted to study the psychological function of this singing. This was to be inberstigated by testing the hypothesis based on thes songs that are sung containing social information. Focusing on social affiliation.
#
# The investigation was based on the reality that social groups share melodies for the songs that they sing to their infants, and that different melodies exist between social groups. thewse shared melodeis may singal to infants that novel indivudals who sing these songs are from the same social group and maybe a signal to this.
#
# the rresearchers recruited 32 parent and infant pairs. these pairs were taught a new lullaby in the first lab visit. The parent was then asked to sing the new lullaby the infantevery day for a 1-2 weeks before the return to the lab for the experimental session.
#
# The Experimental consited of showing th infants to side by side video of two unique individuals. A Baseline gazepropotion score was taken after Baeline score was taken the unfamilar people on the screen began to sing either the learnt or different lullaby. This followed by rewatching the silent video and again the proportion of looking was recorded.

# %% [markdown]
# ## Import data

# %%
# Call github repository
url = "https://raw.githubusercontent.com/ebrlab/Statistical-methods-for-research-workers-bayes-for-psychologists-and-neuroscientists/master/Data/Mehr%20Song%20and%20Spelke%202016%20Experiment%201.csv"
#Import data .csv file into pandas dataframe.
df = pd.read_csv(url)

# Output data frame for evaluation
df.head(1)
# Out:
#     id study_code  exp1  exp2  exp3 exp4 exp5        dob       dot1  \
# 0  101      "LUL"     1     0     0            09-Oct-12  29-Mar-13
#
#         dot2  ... dtword13  dtnoword13 totsing14  babylike14  singcomf14  \
# 0  05-Apr-13  ...        0           0
#
#    totrecord14  othersong14  dtword14  dtnoword14  filter_$
# 0                                   0           0         1
#
# [1 rows x 153 columns]

# %% [markdown]
# ### Clean the data
#
# The analysis below is coducted on experiement 1 data of Mehr et al. (2016), as such the data needs to be cleaned and reduced, before analyis.

# %%
# The data for the first experiment 1 is in the first 32 rows of the dataframe
#
red_df = df.iloc[0:32,]

# %% [markdown]
# ### Data visualisation and exploratory Data analysis

# %%
# Set Seaborn theme for data visualisations.
sns.set_style("white");

# PLotting a histogram and Kernel density estimate of the baseline gaze proportion scores
sns.distplot(red_df["Baseline_Proportion_Gaze_to_Singer"], bins=10);

# %% [markdown]
# # Step 2 - Define the descriptive statistical model \begin{align*}
# y_i &\sim Normal(\mu, \sigma)
# \\ \mu &\sim Normal(0.5, 0.2)
# \\ \sigma &\sim Exponential(0.1)
# \end{align*}
#
# <font size = "3">The formulation for presenting statistical models here follows that used by McElreath (2020) for its intuitive nature. In plain english the model specifies that the dependent variable $y_i$ is distributed normally in terms of the Likelihood with the $\mu$ and $\sigma$ to be estimated. With the prior for the $\mu$ parameter being $Normal(0.5, 0.2)$ and the $\sigma$ being expoentially distributed $Exponential(0.1)$

# %% [markdown]
# # Step 3 - Specifying priors

# %% [markdown]
# ## Prior predictive checks

# %% [markdown]
# ### Visualising priors

# %%
# Visualising priors is a key step of prior predictive checks

# Visualise prior on mean parameter.
x = np.arange(-0.5, 1.5, 0.001)

plt.subplot(1, 2, 1)
plt.plot(x, ss.norm.pdf(x,loc=0.5, scale=0.2));
plt.xlabel("prior on mu");

# Visualise prior on Standard deviation parameter.
x = np.arange(-.01, .1, 0.001)
plt.subplot(1, 2, 2)
plt.plot(x, ss.expon.pdf(x, scale = 0.01));
plt.xlabel("prior on sigma");

# %% [markdown]
# ### SImulating data based on priors
#
# Following the visualisation of the priors for the parameters of the model to
# check how they interact it is important to run prior predcitive check by
# simulating data based on the model.

# %%
# Set seed to allow for the reproduciblity of notebook.
np.random.seed(1)

# Simulate data from the prior for the mean of the model specified above.
sample_mu = np.random.normal(loc= 0.5, scale = .2, size = 1000)
sample_sigma = np.random.exponential(scale = .1, size = 1000)

prior_PC = np.random.normal(loc = sample_mu, scale = sample_sigma, size = 1000)

# Plot the simulated data
sns.distplot(prior_PC, hist = False);

# Plot vertical line of the 2 standard deviatons either side of the simulated data.
plt.vlines((np.mean(prior_PC) + 2 * np.std(prior_PC)), ymin = 0, ymax = 1.8);
plt.vlines((np.mean(prior_PC) - 2 * np.std(prior_PC)), ymin = 0, ymax = 1.8);

# %% [markdown]
# The prior predictive check show that generate reasonable data for child gaze rated by viewers on scale between 0 and 1.

# %% [markdown]
# # Step 4 - Use Bayes rule

# %% [markdown]
# # Stan model of Bayesian One sample t-test

# %%
# Stan model to replciate the frequentist one sample t-test.

One_sample_t_test_model = """

data{

int<lower = 1> N;
vector[N] y;

}

parameters{

// Model paramaters to be estimated

 real<lower=0, upper=1> mu;// Bounded between 0 and 1 because as proportion of gaze scores cannot exceed those bounds
 real<lower=0> sigma; //Standard deviation bounded at 0
 
}

model{

//priors
// Informed prior based on the use of a normal likelihood to estimate mean and standard deviation parameters
// of proportion score that ranges from 0 to 1

mu ~ normal(0.5, 0.2);
sigma ~ exponential(0.01);

// Likliehood
y ~ normal(mu, sigma);

}

generated quantities {

//Generated a real value for difference between the MCMC sample of mu and 0.5.
real diff = mu - 0.5;

// Generating a quantity of a effect size similar to cohen D of a standarised diffence comapring
// a reference mean (here is proportion of 0.5) as would be specified in a one sample t-test
real Cohen_D = (mu - 0.5) / sigma; //effect size
  
real yrep[N];
  
// Generate data for posterior samples
  for (i in 1:N) {
    yrep[i] = normal_rng(mu, sigma);
 }
}
"""

# %%
# Generate python dictionary to pass to Stan model to sample and run Bayesian One sample.
data = {'N': len(red_df),
        'y':  red_df["Baseline_Proportion_Gaze_to_Singer"].values}

# %%
# StanModel function can be called and be passed the model string specified above to compile into C++ code.
sm  = ps.StanModel(model_code = One_sample_t_test_model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_b66616b17eee3e8e110f00fbdbff7dd1 NOW.

# %%
# Fit and sample posterior for the model for the data, taking 2000 samples per 4 chains.
fit = sm.sampling(data = data, iter = 2000, chains = 4, seed = 302675)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-e6f6b7ce631a> in <module>
#       1 # Fit and sample posterior for the model for the data, taking 2000 samples per 4 chains.
# ----> 2 fit = sm.sampling(data = data, iter = 2000, chains = 4, seed = 302675)
#
# ~\Anaconda3\lib\site-packages\pystan\model.py in sampling(self, data, pars, chains, iter, warmup, thin, seed, init, sample_file, diagnostic_file, verbose, algorithm, control, n_jobs, **kwargs)
#     721
#     722         seed = pystan.misc._check_seed(seed)
# --> 723         fit = self.fit_class(data, seed)
#     724
#     725         m_pars = fit._get_param_names()
#
# stanfit4anon_model_b66616b17eee3e8e110f00fbdbff7dd1_3092413989554623907.pyx in stanfit4anon_model_b66616b17eee3e8e110f00fbdbff7dd1_3092413989554623907.StanFit4Model.__cinit__()
#
# ...

# %%
# Output Stan model results
print(fit)
# Out:
# Inference for Stan model: anon_model_b66616b17eee3e8e110f00fbdbff7dd1.
# 4 chains, each with iter=10000; warmup=5000; thin=1;
# post-warmup draws per chain=5000, total post-warmup draws=20000.
#
#            mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu         0.52  2.7e-4   0.03   0.46    0.5   0.52   0.54   0.59  14543    1.0
# sigma      0.18  2.1e-4   0.02   0.14   0.17   0.18    0.2   0.24  13427    1.0
# diff       0.02  2.7e-4   0.03  -0.04-1.1e-3   0.02   0.04   0.09  14543    1.0
# Cohen_D    0.11  1.4e-3   0.18  -0.23-6.2e-3   0.11   0.23   0.46  15470    1.0
# yrep[1]    0.52  1.4e-3   0.19   0.14   0.39   0.52   0.65   0.89  19597    1.0
# yrep[2]    0.52  1.3e-3   0.19   0.15    0.4   0.53   0.65    0.9  19864    1.0
# yrep[3]    0.52  1.4e-3   0.19   0.14   0.39   0.52   0.64   0.89  19683    1.0
# yrep[4]    0.52  1.4e-3   0.19   0.14   0.39   0.52   0.64   0.89  18441    1.0
# ...

# %% [markdown]
# # Post model fit-visualisations - Bayesian one sample Z-test
#
# ## Posterior distributions plots

# %%
# Using arviz built in Bayesian anlysis plot_posterior funcion to display the posterior probabilty distributions
# for the fitted model parameter estimates.
az.plot_posterior(fit, var_names=("mu", "sigma"));
az.plot_posterior(fit, var_names=("diff", "Cohen_D"));

# %% [markdown]
# ## Autocorrelation plots

# %%
# Using the arviz package the autocorrelation of the 4 MCMC chains can be plotted.
az.plot_autocorr(fit, var_names=("mu"));

# %% [markdown]
# The autocorrelation plots do not show any serious autocorrelation problems, as the values quickly decrease to 0.

# %% [markdown]
# ## MCMC traceplots

# %%
az.plot_trace(fit,var_names=("mu", "sigma", "diff", "Cohen_D"));

# %% [markdown]
# The traceplot show good mixing of chains and show a hairy catepillar.

# %% [markdown]
# # Step 5 - Posterior predictive checks

# %%
yrep_df  = pd.DataFrame(fit['yrep']).T.iloc[:,:]
yrep_df
# Out:
#        0         1         2         3         4         5         6      \
# 0   0.263643  0.776090  0.389772  0.463361  0.883971  0.362687  0.751374
# 1   0.784821  0.956485  0.578857  0.611760  0.511413  0.793307  0.639860
# 2   0.617293  0.322500  0.548561  0.120107  0.768398  0.593644  0.463390
# 3   0.594369  0.406525  0.610799  0.388772  0.488330  0.593002  0.735228
# 4   0.584644  0.550696  0.496034  0.692532  0.101543  0.078001  0.491831
# 5   0.712870  0.463207  0.634097  0.803960  0.856776  0.542936  0.558561
# 6   0.596934  0.386763  0.268555  0.193581  0.420760  0.759758  0.439342
# 7   0.575719  0.439250  0.439801  0.379523  0.406486  0.550794  0.813331
# 8   0.596705  0.739533  0.361996  0.351559  0.301018  0.450837  0.484708
# 9   0.640242  0.430505  0.427598  0.899894  0.766344  0.610004  0.906917
# 10  0.803712  0.540377  0.458044  0.520905  0.584326  0.857465  0.528557
# 11  0.781224  0.530415  0.432798  0.361716  0.533653  0.436490  0.466119
# ...

# %%
#Convert pystan fit object to IO for Arviz functions.
data = az.from_pystan(
                posterior=fit,
                posterior_predictive='yrep',
                observed_data=["y"])

# Plot posterior simulated data sets for posterior predictive check
az.plot_ppc(data, data_pairs = {"y" : "yrep"}, num_pp_samples= 100);

# %% [markdown]
# The posterior predictive check has shown that simulated data sets are similar to the original but that the origanl data is rightly skewed from what is simualted from the model. This could mean many things that an alternative better fitting model may need to be fit or that the small amount of data is presenting the reality that infernces are more uncertain. Of course this isnt neccesarilty a problem it just needs to be communicated.

# %% [markdown]
# # Reporting the results of the Bayesian one sample t-test equivalent
#
# <font size = "3">As Kruscke correctly points out there is not standard formula or presentation method for reuslts in journal article like the APA guide for reporting frequentist analysis. It is likely there never will be, because as McElreath (2020) explains, Bayesian data analysis is more like a engineering approach to the problem and the resulting model that is fit will be analysis specific. In addition, as Gabry et al, (2019) argue visualisations maybe even more key so the all the visualtions above would have to be included with any write up. Anyway below the write up as below general follows the advice of Kruscke (2015) chapter 25. In any application though it comes down to the problem to be described an the audience that needs to be convinced. </p><br/>
#
# <h2>Write up</h2><br/>

# %% [markdown]
# # References
#
# Gabry, J., Simpson, D., Vehtari, A., Betancourt, M., & Gelman, A. (2019). Visualization in Bayesian workflow. Journal of the Royal Statistical Society: Series A (Statistics in Society), 182(2), 389-402.
#
# Kruschke, J. (2015). Doing Bayesian data analysis: A tutorial with R, JAGS and Stan. Oxford, England: Academic Press.
#
# McElreath, R. (2020). Statistical rethinking: A Bayesian course with examples in R and Stan.Boca Raton: CRC Press.
#
# Mehr, S. A., Song. L. A., & Spelke, E. S. (2016). For 5-month-old infants, melodies are social. Psychological Science, 27, 486-501.
