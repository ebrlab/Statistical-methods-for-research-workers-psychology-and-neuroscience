# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Bayesian-estimation-equivalent-of-the-one-sample-Z-test" data-toc-modified-id="Bayesian-estimation-equivalent-of-the-one-sample-Z-test-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Bayesian estimation equivalent of the one-sample Z-test</a></span><ul class="toc-item"><li><span><a href="#The-classic-one-sample-z-test" data-toc-modified-id="The-classic-one-sample-z-test-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>The classic one sample z-test</a></span></li></ul></li><li><span><a href="#Bayesian-inference" data-toc-modified-id="Bayesian-inference-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Bayesian inference</a></span></li><li><span><a href="#Steps-of-Bayesian-data-analysis" data-toc-modified-id="Steps-of-Bayesian-data-analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Steps of Bayesian data analysis</a></span></li><li><span><a href="#Step-1---Identify-the-relevant-data-for-question-under-investigation" data-toc-modified-id="Step-1---Identify-the-relevant-data-for-question-under-investigation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Step 1 - Identify the relevant data for question under investigation</a></span><ul class="toc-item"><li><span><a href="#Simulate-the-IQ-scores" data-toc-modified-id="Simulate-the-IQ-scores-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Simulate the IQ scores</a></span></li><li><span><a href="#Visualise-and-explore-the-data" data-toc-modified-id="Visualise-and-explore-the-data-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Visualise and explore the data</a></span></li></ul></li><li><span><a href="#Step-2---Define-the-descriptive-statistical-model" data-toc-modified-id="Step-2---Define-the-descriptive-statistical-model-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Step 2 - Define the descriptive statistical model</a></span></li><li><span><a href="#Step-3---specifying-priors" data-toc-modified-id="Step-3---specifying-priors-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Step 3 - specifying priors</a></span><ul class="toc-item"><li><span><a href="#Prior-predictive-checks" data-toc-modified-id="Prior-predictive-checks-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Prior predictive checks</a></span><ul class="toc-item"><li><span><a href="#Visualising-priors" data-toc-modified-id="Visualising-priors-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Visualising priors</a></span></li><li><span><a href="#prior-predcitive-check---simulating-data-using-priors" data-toc-modified-id="prior-predcitive-check---simulating-data-using-priors-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>prior predcitive check - simulating data using priors</a></span></li></ul></li></ul></li><li><span><a href="#Step-4---Use-Bayes-rule." data-toc-modified-id="Step-4---Use-Bayes-rule.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Step 4 - Use Bayes rule.</a></span></li><li><span><a href="#Stan-model-of-a-Bayesian-Z-test" data-toc-modified-id="Stan-model-of-a-Bayesian-Z-test-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Stan model of a Bayesian Z-test</a></span></li><li><span><a href="#Post-model-fit-visualisations---Bayesian-one-sample-Z-test" data-toc-modified-id="Post-model-fit-visualisations---Bayesian-one-sample-Z-test-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Post model fit-visualisations - Bayesian one sample Z-test</a></span><ul class="toc-item"><li><span><a href="#Posterior-distributions-plots" data-toc-modified-id="Posterior-distributions-plots-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Posterior distributions plots</a></span></li><li><span><a href="#Autocorrelation-plots" data-toc-modified-id="Autocorrelation-plots-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Autocorrelation plots</a></span></li><li><span><a href="#MCMC-traceplots" data-toc-modified-id="MCMC-traceplots-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>MCMC traceplots</a></span></li></ul></li><li><span><a href="#Step-5---Posterior-predictive-checks" data-toc-modified-id="Step-5---Posterior-predictive-checks-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Step 5 - Posterior predictive checks</a></span><ul class="toc-item"><li><span><a href="#Posterior-p-values" data-toc-modified-id="Posterior-p-values-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Posterior p-values</a></span></li></ul></li><li><span><a href="#Reporting-the-results-of-the-Bayesian-one-sample-Z-test-equivalent" data-toc-modified-id="Reporting-the-results-of-the-Bayesian-one-sample-Z-test-equivalent-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Reporting the results of the Bayesian one sample Z-test equivalent</a></span><ul class="toc-item"><li><span><a href="#Write-up" data-toc-modified-id="Write-up-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span><font size="3">Write up</font></a></span></li></ul></li><li><span><a href="#Bayesian-estimation-equivalent-of-the-two-sample-Z-test" data-toc-modified-id="Bayesian-estimation-equivalent-of-the-two-sample-Z-test-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Bayesian estimation equivalent of the two sample Z-test</a></span></li><li><span><a href="#Step-1---indentify-the-relevant-data-for-the-question-under-investigation." data-toc-modified-id="Step-1---indentify-the-relevant-data-for-the-question-under-investigation.-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Step 1 - indentify the relevant data for the question under investigation.</a></span><ul class="toc-item"><li><span><a href="#Simulate-a-second-group-of-data" data-toc-modified-id="Simulate-a-second-group-of-data-13.1"><span class="toc-item-num">13.1&nbsp;&nbsp;</span>Simulate a second group of data</a></span></li><li><span><a href="#Visualise-and-explore-the-data" data-toc-modified-id="Visualise-and-explore-the-data-13.2"><span class="toc-item-num">13.2&nbsp;&nbsp;</span>Visualise and explore the data</a></span></li></ul></li><li><span><a href="#Step-2---Define-the-descriptive-statistical-model" data-toc-modified-id="Step-2---Define-the-descriptive-statistical-model-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Step 2 - Define the descriptive statistical model</a></span></li><li><span><a href="#Step-3---Prior-predictive-checks" data-toc-modified-id="Step-3---Prior-predictive-checks-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Step 3 - Prior predictive checks</a></span></li><li><span><a href="#Step-4---use-Bayes-rule." data-toc-modified-id="Step-4---use-Bayes-rule.-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Step 4 - use Bayes rule.</a></span></li><li><span><a href="#Post-model-fit-visualisations---Bayesian-two-sample-Z-test" data-toc-modified-id="Post-model-fit-visualisations---Bayesian-two-sample-Z-test-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>Post model fit visualisations - Bayesian two sample Z-test</a></span><ul class="toc-item"><li><span><a href="#Posterior-distribution-plots" data-toc-modified-id="Posterior-distribution-plots-17.1"><span class="toc-item-num">17.1&nbsp;&nbsp;</span>Posterior distribution plots</a></span></li><li><span><a href="#Autocorrelation-plots" data-toc-modified-id="Autocorrelation-plots-17.2"><span class="toc-item-num">17.2&nbsp;&nbsp;</span>Autocorrelation plots</a></span></li><li><span><a href="#MCMC-Traceplots" data-toc-modified-id="MCMC-Traceplots-17.3"><span class="toc-item-num">17.3&nbsp;&nbsp;</span>MCMC Traceplots</a></span></li></ul></li><li><span><a href="#Step-5---Posterior-predictive-check---two-groups" data-toc-modified-id="Step-5---Posterior-predictive-check---two-groups-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>Step 5 - Posterior predictive check - two groups</a></span></li><li><span><a href="#Reporting-the-results-of-the-two-sample-Z-test" data-toc-modified-id="Reporting-the-results-of-the-two-sample-Z-test-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Reporting the results of the two sample Z-test</a></span><ul class="toc-item"><li><span><a href="#Write-up" data-toc-modified-id="Write-up-19.1"><span class="toc-item-num">19.1&nbsp;&nbsp;</span>Write up</a></span></li></ul></li><li><span><a href="#References" data-toc-modified-id="References-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>References</a></span></li></ul></div>

# %%
# Import data analysis and visualisation packages
import numpy as np
import pandas as pd
import pystan as ps
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import arviz as az

# %%
# Section of code taken from Stack Overflow to center notebook plots. https://stackoverflow.com/questions/18380168/center-output-plots-in-the-notebook
# I cannot claim to understand it.
from IPython.core.display import HTML as Center

Center(""" <style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style> """)
# Out:
#  <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# # Bayesian estimation equivalent of the one-sample Z-test

# %% [markdown]
# <font size="3">This notebook will be slightly different than the others within this repository of notebooks. That difference will be that the data analysed here will be simulated, where as, in the others will use real world data from studies to demonstrate Bayesian data analysis and the approach of modelling under uncertainty. This notebook aims to offer an ease into this apporach using the following example of a Bayesian equivalent to the classical statistics Z-test.
#
# One reason for using a simulted example for this this Bayesian equivalent to the z-test being is becuase it is a very simple model and a  good ease in example as in a the Z-test the model the variance/standard devation of data generating process (DPG) is assumed to be known  and their is only one model parameter to be estiamted (the $\mu$ of the distribtuion). Additionaly, due to the fact this example is simulated there is no uncertainty as the as the DPG is known. </font>

# %% [markdown]
# ## The classic one sample z-test
# <font size = "3">The one sample Z-test of course calculates a Z statistic taken the sample mean estiamte $\large \bar{X}$ against a null hyptheis $\large\mu_0$ over a known or assumed to be know standard deviation of the population $\large \sigma$.</font>
#
# $$ \large Z = \frac{\bar{X}-\mu_0}{\sigma}$$
#
# <font size = "3">With the Z statistic then being compared to null sampling distribution to determine p-value is less than or equal to the $\large  \alpha$ level determined before the analysis for the NHST.<font >
#
# $$ \large H_0:\mu = \mu_0$$
# $$ \large H_1:\mu\neq \mu_0$$

# %% [markdown]
# # Bayesian inference
# <font size = "3"> Following the quick description of the classic Z-test above its important to keep in mind that Bayesian analysis inference are all derived from the applciation of Bayes rule $P(\theta \mid y) = \large \frac{P(y \mid \theta) \, P(\theta)}{P(y)}$ and as such while the following description of the Bayesian model is an equivalent to the Z-test, it is fundamentally different, becuase its uses fully probabilistic modelling and the infernce is based on sampling distributions</font>
#
# <font size = "1"> For a fuller description see the Practicing Bayesian statistics markdown file within the Github repository.</font>

# %% [markdown]
# # Steps of Bayesian data analysis
#
# <font size = "3"> Kruscke (2015) offers a step by step formulation for how to conduct a Bayesian analysis:
#
# 1. Identify the relevant data for question under investigation.
#
# 2. Define the descriptive (mathematical) model for the data.
#
# 3. Specify the Priors for the model. In the case of scientific research publication is the goal, as such the priors must be accepted by a skeptical audience. Much of this can be achieved using prior predcitve checks to acsetain os the priors are reasonable.
#
# 4. Using Bayes rule estimate the posterior for the parameters of the model using the likelihood and priors. Then interprete and the posterior
#
# 5. Conduct model checks. i.e. Posterior predcitive checks.</font>
#
# <font size = "1">This notebook will follow this approach generally.</font>

# %% [markdown]
# #  Step 1 - Identify the relevant data for question under investigation
#
# <font size = "3">The example below is based on simulating and analysing IQ scores, a highly understood phenemomena in the general population in terms of the standard deviation; due the standardisations of the test with an average IQ set at 100 and standard deviation of 15 (Warne, 2020). In additon to this using IQ data has become standard in Bayesian data analysis teaching (Kruschke, 2015) for pedagogical reasons and as such is used here.</font>

# %% [markdown]
# ## Simulate the IQ scores

# %%
# Set random seed so the analysis to follow is reproducible.
np.random.seed(1)

# Generating 100 random samples from a normal distribution with mean of 100 and standard deviation of 15, representing 
# IQ scores, that are analysed below.
IQ = np.round(np.random.normal(loc = 100, scale = 15, size = 100))

# %% [markdown]
# ## Visualise and explore the data

# %%
# Set Seaborn theme for data visualisations.
sns.set_style("whitegrid")

# Plot  a histogram of the data with a normal distribution imposed.
sns.distplot(IQ, fit = stats.norm, kde= False);
plt.xlabel("IQ Scores");

# %% [markdown]
# <font size ="3">From eyeballing the data its looks normally distributed. This of course is unsurprising seeing as it has been randomly generated from a normal distribution. This point thoough is only brought up as even though the data visually looks normally distributed it is not a justification for selecting a normal likelihood to model the data. When deciding on how to model the data the likelihood should be based on attempting to model the Data Generating Process (DGP) this of course is unknown, but there is a level of pragmatic choice. As as analyst being open to critisism to  modelling choices can helpful to improve  modelling and ultimately improve the inferences and understanding of the phenomena.
#
# However as this notebook is demonstrating a Bayesian Z-test equivalent a normal likelihood will be used as that is an assumption of the Z-test, and is an assumption of the Bayesian model specified abovr in section 5, however using full probability models and Bayes rule for our inference allows much greater flexibilty, which will be demonstrated in the other repository notebooks.<font>

# %% [markdown]
# # Step 2 - Define the descriptive statistical model
#
#
# \begin{align*}
# y_i &\sim Normal(\mu,15)
# \\ \mu &\sim Normal(100, 20)
# \end{align*}
#
# <font size = "3">The formulation for presenting statistical models here follows that used by McElreath (2020) for its intuitive nature. In plain english the model specifies that the dependent variable $y_i$ (IQ scores)  is distributed normally in terms of the Likelihood with a known standard deviation of 15 but an unkown $\mu$ that is to be estimated with a normally distributed prior probability  on $\mu$ that has a $ \mu = 100$ and $ \sigma = 20$.</font>

# %% [markdown]
# # Step 3 - specifying priors

# %% [markdown]
# ## Prior predictive checks

# %% [markdown]
# ### Visualising priors
# The first step in prior predictive check is to visualise the priors within the model for the parameters being modelled.
# As the statistical model specified above show their is only one prior in the analysis and the standard deviation
# is assumed to be known at 15 and is not estimated.

# %%
# PLot the prior of the model for describing possible mean values of the DGP for IQ scores. This is quite a broad prior
# and shouldnt be too contrverial to a skeptical audience as it assigns high probability means for IQ ranging from 
# 60 and 140.

#Creat range of points to plot the pdf function on
Range_of_X_axis = np.arange(60, 140, 0.001)

#Plot the normal pdf that shows our prior on the means of the probable mean values for IQ
plt.plot(Range_of_X_axis, stats.norm.pdf(Range_of_X_axis, loc = 100, scale = 20));
plt.xlabel("95% prior probability on the mean value of IQ");

# %% [markdown]
# <font size =3>Note that that the pdf is cut of at 2 standard deviations above as this is where 95% of the probability mass lies for the probable values of $mu$ and shows how broad the prior is in the case of probable IQ scores, follwing the 68–95–99.7 rule of normal distributions.<\font>

# %% [markdown]
# ### prior predcitive check - simulating data using priors

# %%
# Following visualisng the prior for the only parameter that will be estimated within the model 
# we can  generate simulated data based on this prior and assumed known standard deviation of 15 for IQ scores.

# Set seed to allow for the reprodcuiblity of notebook.
np.random.seed(1)

# Simulate data from the prior for the mean of the model specified above.
sample_mu = np.random.normal(loc= 100, scale = 20, size = 1000)

# Generate a simulated data set of IQ scores based on the prior for the means and the assumed known Standard deviation (15)
# and the normal likelihood.
prior_PC = np.random.normal(loc = sample_mu, scale = 15, size = 1000)

# Plot the simulated data density
sns.set_style("whitegrid");
sns.distplot(prior_PC, hist=False);
plt.xlabel("Prior Predictive simulated IQ scores");

# Plot vertical line of the 2 standard deviatons either side of the simulated data.
plt.vlines((np.mean(prior_PC) + 2 * np.std(prior_PC)), ymin=0, ymax=0.018);
plt.vlines((np.mean(prior_PC) - 2 * np.std(prior_PC)), ymin=0, ymax=0.018);

# %% [markdown]
# <font size = 3>As the prior predictive check of our priors shows that the simulated data is reasonable within the understanding of IQ, whilst sldo incoprortaing s reasonble uncertainty for a skeptical audience in that our priors enocde that it is 95% probable to observe individuals with IQ's as low as 50 and as high as 150.</font>

# %% [markdown]
# # Step 4 - Use Bayes rule.
#
# The software of choice to conduct Bayesian inference on the data here is Stan and the model is specified below.

# %% [markdown]
# # Stan model of a Bayesian Z-test

# %% [markdown]
# <font size = 3>Below the statistical model defined above in section 5 of this notebook is coded in Stan code for compilation below</font>

# %%
One_z_test_model = """

data{
// Number of IQ data points
int<lower=1> N;

// Define a vector of dependent variable (IQ scores) values
vector[N] y; 
}

parameters{
// Because in the traditional Z-test we assume we know the standard deviation of the DGP
// we do not estimate it and the only unknown is the mu (mean) parameter in the normal 
// model specified below.
real mu;
}

model{
// The priors
mu ~ normal(100, 20);

// The likelihood
  y ~ normal(mu, 15);
}

generated quantities{

// Generated a real value for difference between the MCMC samples of mu and 100.
real diff = mu - 100;

// Cohen D calculation of the MCMC samples to get the standardised effect size
// for the diffence between the mean estimates and 100.
real Cohen_D = (mu - 100) / 15;

// Generate posterior p-value variable 
int<lower = 0, upper = 1> mean_pv;

{
real yrep[N];
  // Generate data for posterior samples
  for (i in 1:N) {
    yrep[i] = normal_rng(mu, 15);  
   }
}

mean_pv = mean(yrep) > mean(y);
}

"""

# %% [markdown]
# The Stan model above takes the data in the model block, the only parameter in this Z-test equivalent to be estimated is $\large \mu$ and as such is specified in the parameters block. The model itself is then defined in the model block, this is where most of the action happens, and the postersior is estimated using Stan NUTS HMC sampler by taking the prior on $\mu$ and the likelihood for the IQ scores to estimate the posterior.

# %%
# Stan models are complied into C++ and this is what the funtion belwo is dong
sm = ps.StanModel(model_code = One_z_test_model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_eef40b37712af90293d0107001609572 NOW.

# %%
# To use pystan the data must be stored in a python dictionary that coincides with what was declared in the data
# block of the stan model above, in order, that it can to passed to  the compiled stan model for fitting below.
data = {'N': len(IQ),
        'y': IQ
       }

# %%
# Fit the One_z_test_model specified above.
fit = sm.sampling(data = data, iter = 2000, chains = 4, seed = 1, warmup = 1000)

# 2000 iterations of MCMC samples with half being used as warmup, within 4 indepedent chains, 
# seed is set for reprodcubiltiy, however due to stocahstic nature of sapling there may 
# be slight variation across machines.

# %%
# Print the ouput for the model
#print(fit)

# %% [markdown]
# Table of key model fit results
#
# |    Parameter  | Posterior mean  |    2.5%     |     97.5%   | R_Hat      |
# | -----------   | -----------     |-----------  |-----------  |----------- |
# |     Mean      |    100.93       |   98.01     |   103.75    |     1      |
# |  Difference   |      0.93       |   -1.99     |    3.75     |     1      |
# |   Cohen D     |       0.06      |    -0.13    |      0.25   |     1      |

# %% [markdown]
# # Post model fit-visualisations - Bayesian one sample Z-test
# The arviz package offers many useful functions for plotting MCMC samples of the posteriors produced by Bayesian data analysis

# %% [markdown]
# ## Posterior distributions plots

# %%
# Using the arviz package the posteriors can be plotted from the MCMC samples
az.plot_posterior(fit, var_names=("mu", "diff",
                                  "Cohen_D"));

# %% [markdown]
# The posterior above shows that the simulated $\mu$ of 100 is captures and there no difference

# %% [markdown]
# ## Autocorrelation plots

# %%
# Using the arviz package the autocorrelation of the 4 MCMC chains can be plotted.
az.plot_autocorr(fit, var_names=("mu"));

# %% [markdown]
# The autocorrelation plots do not show any serious autocorrelation problems, as the values quicly decrease to 0.

# %% [markdown]
# ## MCMC traceplots

# %%
# Using the arviz package the traceplots of the 4 MCMC chains can be plotted.
az.plot_trace(fit, var_names=("mu", "diff", "Cohen_D"));

# %% [markdown]
# The traceplot show good mixing of chains and show a hairy catepillar.

# %% [markdown]
# # Step 5 - Posterior predictive checks

# %%
# Create a pandas dataframe of simulated datasets genreted from the posterior check. #
# the dataframe is a subet of the first 202 simualted data sets. (Stan generates as many datasets as Iterations)
yrep_df  = pd.DataFrame(fit['yrep']).T.iloc[:,0:20]
yrep_df.sum(axis=0)/100
# Out:
#              0           1           2           3           4           5  \
# 0    84.848462  131.867029   93.265010  108.451315  115.579848   98.557346
# 1   116.369576  100.640999  115.045786   82.904724  102.498502   86.496291
# 2   100.219581  109.353252   58.645870   94.220118  110.472074   86.477827
# 3   135.034934   95.836105  111.990254   90.001345  126.470947  133.493050
# 4    91.808435  125.467726  124.002187   89.335705  122.222958  103.037710
# ..         ...         ...         ...         ...         ...         ...
# 95   76.484358  105.357628  104.163389   81.174311  132.573452   83.693547
# 96   80.558628  110.734504   99.668916   92.680707  100.496532  101.087097
# 97   94.322151   90.870518   95.267900  107.425077  104.246453  117.649132
# 98   89.200130   79.457924  107.911527   86.902444   98.716387  102.183538
# 99   85.848889  112.535169   80.538616   83.550750  108.215934  116.741163
#
# ...

# %%
# Cpnbert the pystan into Arviz infernce object for use in plotting functions
data = az.from_pystan(
                posterior=fit,
                posterior_predictive='yrep',
                observed_data=["y"])
                
az.plot_ppc(data, data_pairs = {"y" : "yrep"}, num_pp_samples= 100);

# %% [markdown]
#                                 figure 1

# %% [markdown]
# The posterior samples show that the simulated datasets can capture the orignal data quite well

# %% [markdown]
# ## Posterior p-values

# %%
az.plot_bpv(IQ, kind="t_stat", t_stat="0.5")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-ff14a84924dc> in <module>
# ----> 1 az.plot_bpv(IQ, kind="t_stat", t_stat="0.5")
#
# AttributeError: module 'arviz' has no attribute 'plot_bpv'

# %% [markdown]
# # Reporting the results of the Bayesian one sample Z-test equivalent
#
# <font size = "3">As Kruscke correctly points out there is not standard formula or presentation method for reuslts in journal article like the APA guide for reporting frequentist analysis. It is likely there never will be, because as McElreath (2020) explains Bayesian data analysis is more like a engineering approach to the problem and the resulting model that is fit will be analysis specific. In addition, as Gabry et al, (2017) argue visualisations maybe even more key so the all the visualtions above would have to be included with any write up. Anyway below the write up as  below genral follows the advice of Kruscke (2015) chapter 25. In any application though it comes down to the problem to be described an the audience that needs to be convinced. </p><br/>
#
# <h2>Write up</h2><br/>
#
# <font size = "3"> Four chains were ran with 2000 MCMC samples each disaring the first 1000 warm up samples. The data was analsyed using the model described above with the mean being estimated as the standard deviation of the normal likelihood was modelled as known at a value of 15. The posterior convergence was examined using autocorreltion and traceplots (in a paper referncing approapraite figures here will be of value). The most credible value of $\mu$ = 100.88 (95% CrI [97.94, 103.78]) for the IQ scores. Posterior predctive checks showed that the model could reasoble recover the orignal data set. see figure </font>

# %% [markdown]
# ==========================================================================================================================

# %% [markdown]
# # Bayesian estimation equivalent of the two sample Z-test
# Below the model will be extended to estimate two groups in a classical z-test Bayesian estimation equivalent

# %% [markdown]
# # Step 1 - indentify the relevant data for the question under investigation.

# %% [markdown]
# ## Simulate a second group of data
# For the analsyis below we need to simulate a second group of IQ scores.

# %%
# Set seed for reproducible notebook
np.random.seed(1)

# Simulation seocnd group of 100 Independent IQ scores from a normal distribtuion but this
#time with a mean of 110 and Standard deviation of 15
IQ_2 = np.round(np.random.normal(loc = 110, scale = 15, size = 100))

# %% [markdown]
# ## Visualise and explore the data

# %%
# Set Seaborn theme for data visualisations.
sns.set_style("whitegrid")

# Plot a histogram of the first group IQ data with a normal distribution imposed.
sns.distplot(IQ, fit = stats.norm, kde= False);
plt.xlabel("IQ Scores");

# Plot a histogram of the first group IQ data with a normal distribution imposed.
sns.distplot(IQ_2, fit = stats.norm, kde= False);
plt.xlabel("IQ Scores");

# %% [markdown]
# # Step 2 - Define the descriptive statistical model
#
# \begin{align}
# y_i{_k} &\sim Normal(\mu{_k},15)
# \\
# \mu{_k} &\sim Normal(100, 20)
# \\
# \label{eq:1}
# \end{align}
#
# The model above in plain english states that the depedent variable of (IQ) for the k groups (two here) are distributed normally, with the prior specifying the mu for IQ are distributed normally with a mean of 100 being the most probable  $\mu$ value for being IQ 100 but with a standard deviation of 20.
#
# <font size = 1> Note to reader in this model the prior is build so that they are the same for both the $mu$ estimations for the separtae groups, but this is not a neccesity and separate priors can be set<\font>

# %% [markdown]
# # Step 3 - Prior predictive checks
# as the model priors are the same as above for both groups for PPC see section 6 above

# %% [markdown]
# # Step 4 - use Bayes rule.
# <font size = 3>Below the statistical model defined above in section  of this notebook is coded in Stan code for compilation below</font>

# %%
Two_z_test_model = """

data{

// Number of IQ data points for the two groups which are the same.
int<lower=1> N;

// Vector of dependent variable (IQ) values defined for the two groups
vector[N] y_1; 
vector[N] y_2;

}

parameters{

// Because in the traditional Z-test we assume we know the standard deviation of the data generating process
// we do not estimate it and the only unknown to be modelled is the mu parameter in the normal likelihood
// specified below in the model block.
real mu_1;
real mu_2;

}

model{

//Priors
mu_1 ~ normal(100, 20);
mu_2 ~ normal(100, 20);


//Likelihood
y_1 ~ normal(mu_1, 15);
y_2 ~ normal(mu_2, 15);

}

generated quantities{

// Unstandardised difference between the MCMC samples of the two posteriors
// for the two groups modelled above
real diff = mu_1 - mu_2;


// Calculating a standardised Cohen D measure between the two groups
real  Cohen_D = (mu_1 - mu_2) / 15;


//Posterior predictive check code
real y1rep[N];
real y2rep[N];
  
  // Generate simulated data from posterior samples
  for (i in 1:N) {
    y1rep[i] = normal_rng(mu_1, 15);
 }
 
  // Generate simulated data for posterior samples
  for (i in 1:N) {
    y2rep[i] = normal_rng(mu_2, 15);
 } 
}

"""

# %%
# Compile stan model into C++ code
sm_2 = ps.StanModel(model_code = Two_z_test_model);
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_616880cb4b6ec21a5302fe0cd9683c51 NOW.

# %%
# Generate a python dictionary for passing to pass Stan for fitting the model above.
data_2 = {'N': len(IQ),
          'y_1': IQ,
          'y_2': IQ_2}

# %%
# Fit two sample z-test model to the data.
fit_2 = sm_2.sampling(data = data_2, iter = 2000, chains = 4, seed = 1, warmup = 1000)

# %%
# print out the results for the two sample Bayesian z-test model fit for 
#print(fit_2)

# %% [markdown]
# # Post model fit visualisations - Bayesian two sample Z-test

# %% [markdown]
# ## Posterior distribution plots

# %%
# Using the arviz package the posteriors can be plotted from the MCMC samples 
az.plot_posterior(fit_2, var_names=("mu_1", "mu_2" ));
az.plot_posterior(fit_2, var_names=("diff", "Cohen_D" ));

# %% [markdown]
# ## Autocorrelation plots

# %%
az.plot_autocorr(fit_2, var_names=("mu_1", "mu_2", "diff", "Cohen_D"));

# %% [markdown]
# Autocorrelation plots show little issue in terms of autocorreltion with the values centered around 0.

# %% [markdown]
# ## MCMC Traceplots

# %%
az.plot_trace(fit_2, var_names=("mu_1", "mu_2"));

# %% [markdown]
# Traceplots show good mixing of the Markow chains and show a hairy catepillar.

# %% [markdown]
# # Step 5 - Posterior predictive check - two groups

# %%
data = az.from_pystan(
                posterior=fit_2,
                posterior_predictive='y1rep',
                observed_data=["y_1"])
                
az.plot_ppc(data, data_pairs = {"y_1" : "y1rep"}, num_pp_samples=100);
plt.xlabel("IQ Scores");

data = az.from_pystan(
                posterior=fit_2,
                posterior_predictive='y2rep',
                observed_data=["y_2"])
                
az.plot_ppc(data, data_pairs = {"y_2" : "y2rep"}, num_pp_samples=100);
plt.xlabel("IQ Scores");

# %% [markdown]
# # Reporting the results of the two sample Z-test
# see section (9) of this notebook for quick discussion on the lack of clarity in reporting Bayesian analyses.
#
# ## Write up

# %% [markdown]
# # References
#
# Gabry, J., Simpson, D., Vehtari, A., Betancourt, M., & Gelman, A. (2019). Visualization in Bayesian workflow. Journal of the Royal Statistical Society: Series A (Statistics in Society), 182(2), 389-402.
#
# Kruschke, J. (2015). Doing Bayesian data analysis: A tutorial with R, JAGS and Stan. Oxford, England: Academic Press.
#
# McElreath, R. (2020). Statistical rethinking: A Bayesian course with examples in R and Stan. Boca Raton: CRC Press.
#
# Warne, R., T. (2020). In the know: Debunking 35 myths about human intelligence. New york, NY: Cambridge University Press.
